# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %%
data01=pd.read_excel("EMPIR_PhotoLED_SPECTRAL_DATABASE_version_2.xlsx",sheet_name="DATA", header= None)

# %%
data01
# Out:
#                                0            1            2            3     \
# 0                 CCT / K (min Duv)  1705.352314  1713.387538  1723.057803
# 1    CCT / K (MacCamy, not precise)  1736.929722  1746.038149   1751.22689
# 2                                Rf    52.026891    53.393764    59.853801
# 3                                Ra    36.854868    58.611153    48.940549
# 4                                R9  -111.405013   -44.358968   -67.801535
# ..                              ...          ...          ...          ...
# 474                             826            0            0     0.000428
# 475                             827            0            0     0.000404
# 476                             828            0            0      0.00043
# 477                             829            0            0     0.000398
# 478                             830            0            0     0.000383
#
# ...

# %%
data = data01.drop([0,1,2,3,4,5,6,7])

data02 = data.drop([0], axis=1)
data02
# Out:
#          1         2         3         4         5         6         7     \
# 8    0.000023  0.000034         0  0.000088  0.000026  0.000054  0.000085
# 9     0.00002  0.000024         0  0.000074  0.000014  0.000067  0.000098
# 10   0.000024  0.000028         0  0.000075  0.000023  0.000041  0.000089
# 11   0.000015  0.000028         0  0.000051  0.000032  0.000038  0.000067
# 12   0.000027   0.00003         0  0.000073  0.000004  0.000051  0.000073
# ..        ...       ...       ...       ...       ...       ...       ...
# 474         0         0  0.000428  0.000056  0.000012  0.000038  0.000332
# 475         0         0  0.000404  0.000052  0.000026  0.000046  0.000336
# 476         0         0   0.00043  0.000053  0.000028  0.000044  0.000332
# 477         0         0  0.000398  0.000043  0.000024   0.00004  0.000314
# 478         0         0  0.000383   0.00007 -0.000003  0.000051  0.000306
#
#     8    9         10    ...      1485      1486      1487 1488      1489  \
# ...

# %% [markdown]
# 703674 个
#
# 471*1494

# %%
data_cleared = data02.values
print(data_cleared)
# Out:
#     0         1         2         3         4         5         6     \
# 8    360  0.000023  0.000034         0  0.000088  0.000026  0.000054
# 9    361   0.00002  0.000024         0  0.000074  0.000014  0.000067
# 10   362  0.000024  0.000028         0  0.000075  0.000023  0.000041
# 11   363  0.000015  0.000028         0  0.000051  0.000032  0.000038
# 12   364  0.000027   0.00003         0  0.000073  0.000004  0.000051
# ..   ...       ...       ...       ...       ...       ...       ...
# 474  826         0         0  0.000428  0.000056  0.000012  0.000038
# 475  827         0         0  0.000404  0.000052  0.000026  0.000046
# 476  828         0         0   0.00043  0.000053  0.000028  0.000044
# 477  829         0         0  0.000398  0.000043  0.000024   0.00004
# 478  830         0         0  0.000383   0.00007 -0.000003  0.000051
#
#          7    8    9     ...      1485      1486      1487 1488      1489  \
# ...

# %%
data_cleared
# Out:
# array([[2.2757918125842892e-05, 3.399140921248083e-05, 0, ..., 0, 0,
#         -1.4641251332350348e-06],
#        [1.9919133402337825e-05, 2.3700268496282506e-05, 0, ...,
#         -2.3619574765657763e-07, 0, -7.864368065780602e-07],
#        [2.426599233262612e-05, 2.7677856950898395e-05, 0, ..., 0, 0,
#         -1.4641251332350348e-06],
#        ...,
#        [0, 0, 0.00043048149708697887, ..., 0, 0, 0],
#        [0, 0, 0.0003976583840582494, ..., 0, 0, 0],
#        [0, 0, 0.000382703643050606, ..., 0, 0, 0]], dtype=object)

# %%
np.save("cleandata.npy", data_cleared)

# %%
data02.to_csv("rowdata")

# %%
data.shape
