# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA

# %% [markdown]
# load data

# %%
data = np.load("cleandata.npy", allow_pickle=True)
pca = PCA(n_components=8,whiten=False)
pca.fit(data)
data_mean = pca.mean_
data_withmax = pca.components_
data_PCA = pca.transform(data)

# %% [markdown]
# 可视化

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data_PCA)
# Out:
# [<matplotlib.lines.Line2D at 0x7fe2fa825d50>,
#  <matplotlib.lines.Line2D at 0x7fe2fa825db0>,
#  <matplotlib.lines.Line2D at 0x7fe2fa825de0>,
#  <matplotlib.lines.Line2D at 0x7fe2fa825ed0>,
#  <matplotlib.lines.Line2D at 0x7fe2fa825fc0>,
#  <matplotlib.lines.Line2D at 0x7fe2fa8260b0>,
#  <matplotlib.lines.Line2D at 0x7fe2fa824c40>,
#  <matplotlib.lines.Line2D at 0x7fe2fa826170>]
